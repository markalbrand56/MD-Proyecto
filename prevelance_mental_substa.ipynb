# %% [markdown]
# # Resumen variables numéricas
# ## prevalence-by-mental-and-substa

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# ignore all FutureWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# con pandas, leer une xlsx
excel_file = pd.ExcelFile('Mental health Depression disorder Data (1).xlsx')

# Sheet prevalence-by-mental-and-substa
dfs = {}  # Diccionario para almacenar los DataFrames
for sheet_name in excel_file.sheet_names:
    dfs[sheet_name] = excel_file.parse(sheet_name)

# %%
# Sheet prevalence-by-mental-and-substa
prevelance_mental_substa = dfs['prevalence-by-mental-and-substa']

# %%
prevelance_mental_substa.head()
# Out:
#         Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0  Afghanistan  AFG  1990           0.160560              0.697779
# 1  Afghanistan  AFG  1991           0.160312              0.697961
# 2  Afghanistan  AFG  1992           0.160135              0.698107
# 3  Afghanistan  AFG  1993           0.160037              0.698257
# 4  Afghanistan  AFG  1994           0.160022              0.698469
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0              0.101855               4.828830                1.677082
# 1              0.099313               4.829740                1.684746
# 2              0.096692               4.831108                1.694334
# 3              0.094336               4.830864                1.705320
# 4              0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %% [markdown]
# ### Variables numéricas

# %%
prevelance_mental_substa.dtypes
# Out:
# Entity                        object
# Code                          object
# Year                           int64
# Schizophrenia (%)            float64
# Bipolar disorder (%)         float64
# Eating disorders (%)         float64
# Anxiety disorders (%)        float64
# Drug use disorders (%)       float64
# Depression (%)               float64
# Alcohol use disorders (%)    float64
# dtype: object

# %% [markdown]
# | Nombre                    | Tipo de Dato | Tipo de variable      |
# |---------------------------|--------------|-----------------------|
# | Entity                    | object       | Cualitativa Nominal   |
# | Code                      | object       | Cualitativa Nominal   |
# | Year                      | int64        | Cuantitativa Discreta |
# | Schizophrenia (%)         | float64      | Cuantitativa Continua |
# | Bipolar disorder (%)      | float64      | Cuantitativa Continua |
# | Eating disorders (%)      | float64      | Cuantitativa Continua |
# | Anxiety disorders (%)     | float64      | Cuantitativa Continua |
# | Drug use disorders (%)    | float64      | Cuantitativa Continua |
# | Depression (%)            | float64      | Cuantitativa Continua |
# | Alcohol use disorders (%) | float64      | Cuantitativa Continua |

# %% [markdown]
# ### Análisis de dispersión de las variables numéricas

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(data=prevelance_mental_substa[['Schizophrenia (%)', 'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)', 'Drug use disorders (%)']])
plt.title('Diagrama de Caja y Bigotes')
plt.show()

# %% [markdown]
# Las variables analizadas están todas en términos de porcentajes, por lo que se puede decir que todas las variables están en la misma escala.
# Con el diagrama anterior se puede observar que la variable con menos dispersión es la de Schizophrenia, mientras que la variable con mayor dispersión es la de Anxiety disorders.

# %% [markdown]
# ### Análisis de variables cuantitativas

# %% [markdown]
# #### Histogramas

# %% [markdown]
# ##### Year
# Tipo de distribución: Uniforme

# %%
# Year
plt.hist(prevelance_mental_substa['Year'], bins=10)
plt.title('Histograma de Year')
plt.show()

# %% [markdown]
# ##### Schizophrenia
# Tipo de distribución: Binomial negativa

# %%
# Schizophrenia
plt.hist(prevelance_mental_substa['Schizophrenia (%)'], bins=10)
plt.title('Histograma de Schizophrenia')
plt.show()

# %% [markdown]
# ##### Bipolar disorder
# Tipo de distribución: Binomial

# %%
# Bipolar disorder
plt.hist(prevelance_mental_substa['Bipolar disorder (%)'], bins=10)
plt.title('Histograma de Bipolar disorder')
plt.show()

# %% [markdown]
# ##### Eating disorders
# Tipo de distribución: Geométrica

# %%
# Eating disorders
plt.hist(prevelance_mental_substa['Eating disorders (%)'], bins=10)
plt.title('Histograma de Eating disorders')
plt.show()

# %% [markdown]
# ##### Anxiety disorders
# Tipo de distribución: Log-normal

# %%
# Anxiety disorders
plt.hist(prevelance_mental_substa['Anxiety disorders (%)'], bins=10)
plt.title('Histograma de Anxiety disorders')
plt.show()

# %% [markdown]
# ##### Drug use disorders
# Tipo de distribución: Geométrica

# %%
# Drug use disorders
plt.hist(prevelance_mental_substa['Drug use disorders (%)'], bins=10)
plt.title('Histograma de Drug use disorders')
plt.show()

# %% [markdown]
# ##### Depression
# Tipo de distribución: Log-normal

# %%
# Depression
plt.hist(prevelance_mental_substa['Depression (%)'], bins=10)
plt.title('Histograma de Depression')
plt.show()

# %% [markdown]
# ##### Alcohol use disorders
# Tipo de distribución: Binomial negativa

# %%
# Alcohol use disorders
plt.hist(prevelance_mental_substa['Alcohol use disorders (%)'], bins=10)
plt.title('Histograma de Alcohol use disorders')
plt.show()

# %% [markdown]
# #### Análisis de correlación
# Dentro de este set de datos, se puede observar que las variables númericas con mayor correlación son:
# - Bipolar disorder y Eating disorders
# - Eating disorders y Anxiety disorders
# - Bipolar disorder y Anxiety disorders

# %%
matriz_correlacion_pms = prevelance_mental_substa[['Schizophrenia (%)', 'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)', 'Drug use disorders (%)']].corr()

matriz_correlacion_pms
# Out:
#                            Schizophrenia (%)  Bipolar disorder (%)  \
# Schizophrenia (%)                   1.000000              0.198456
# Bipolar disorder (%)                0.198456              1.000000
# Eating disorders (%)                0.668816              0.708055
# Anxiety disorders (%)               0.469325              0.663745
# Depression (%)                      0.167478              0.148557
# Alcohol use disorders (%)          -0.059207              0.079694
# Drug use disorders (%)              0.475203              0.363871
#
#                            Eating disorders (%)  Anxiety disorders (%)  \
# Schizophrenia (%)                      0.668816               0.469325
# Bipolar disorder (%)                   0.708055               0.663745
# Eating disorders (%)                   1.000000               0.698026
# Anxiety disorders (%)                  0.698026               1.000000
# Depression (%)                         0.240716               0.379012
# ...

# %%
# Pairplot
sns.pairplot(prevelance_mental_substa[['Schizophrenia (%)', 'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)', 'Drug use disorders (%)']])
plt.title('Pairplot')
plt.show()

# %%
# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacion_pms, annot=True)
plt.title('Mapa de Calor')
plt.show()

# %% [markdown]
# ### Análisis de variables cualitativas

# %% [markdown]
# #### Tablas de frecuencia

# %% [markdown]
# ##### Entity

# %%
prevelance_mental_substa['Entity'].value_counts()
# Out:
# Entity
# Afghanistan                     28
# Niger                           28
# North Africa and Middle East    28
# North America                   28
# North Korea                     28
#                                 ..
# Grenada                         28
# Guam                            28
# Guatemala                       28
# Guinea                          28
# Zimbabwe                        28
# Name: count, Length: 231, dtype: int64

# %% [markdown]
# ##### Code

# %%
prevelance_mental_substa['Code'].value_counts()
# Out:
# Code
# AFG    28
# NZL    28
# NER    28
# NGA    28
# PRK    28
#        ..
# GRC    28
# GRL    28
# GRD    28
# GUM    28
# ZWE    28
# Name: count, Length: 196, dtype: int64
